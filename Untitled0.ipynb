# %% [markdown]
# <a href="https://colab.research.google.com/github/Rabbiya-tabassum/linear-regression/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv('Position_Salaries.csv')

x = df.iloc[:,1:2].values
y = df.iloc[:,2].values
y
# Out:
# array([  45000,   50000,   60000,   80000,  110000,  150000,  200000,
#         300000,  500000, 1000000])

# %%
regression=LinearRegression()
regression.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred= regression.predict(x)
print('Predicted response:',y_pred, sep='\n')

score = r2_score(y,y_pred)
print(score)
# Out:
# Predicted response:
# [-114454.54545455  -33575.75757576   47303.03030303  128181.81818182
#   209060.60606061  289939.39393939  370818.18181818  451696.96969697
#   532575.75757576  613454.54545455]
# 0.6690412331929895

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='green')
plt.title('simple linear regression')
plt.xlabel('position level')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg2=PolynomialFeatures(degree=2)
x_poly=poly_reg2.fit_transform(x)
regression_poly_2=LinearRegression()
regression_poly_2.fit(x_poly,y)
y_pred=regression_poly_2.predict(x_poly)
print('Predicted response:', y_pred,sep='\n')

score=r2_score(y,y_pred)
print(score)
# Out:
# Predicted response:
# [118727.27272727  44151.51515151   8439.39393939  11590.90909091
#   53606.06060606 134484.84848485 254227.27272727 412833.33333333
#  610303.03030303 846636.36363636]
# 0.9162082221443942

# %%
plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='green')
plt.title('simple linear regression')
plt.xlabel('position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_reg3=PolynomialFeatures(degree=3)
x_poly=poly_reg3.fit_transform(x)
regression_poly_3=LinearRegression()
regression_poly_3.fit(x_poly,y)
y_pred=regression_poly_3.predict(x_poly)
print('Predicted response:', y_pred,sep='\n')

score=r2_score(y,y_pred)
print(score)
# Out:
# Predicted response:
# [ 14902.09790211  78759.90675991  94960.37296037  88223.77622378
#   83270.3962704  104820.51282052 177594.40559441 326312.35431236
#  575694.63869463 950461.53846152]
# 0.9812097727913366

# %%
plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='green')
plt.title('simple linear regression')
plt.xlabel('position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_reg3=PolynomialFeatures(degree=4)
x_poly=poly_reg3.fit_transform(x)
regression_poly_3=LinearRegression()
regression_poly_3.fit(x_poly,y)
y_pred=regression_poly_3.predict(x_poly)
print('Predicted response:', y_pred,sep='\n')

score=r2_score(y,y_pred)
print(score)
# Out:
# Predicted response:
# [ 53356.64335675  31759.90675984  58642.1911421   94632.86713282
#  121724.94172495 143275.05827509 184003.49650352 289994.17249417
#  528694.63869462 988916.08391612]
# 0.9973922891706614

# %%
plt.scatter(x,y,color='red')
plt.plot(x,y_pred,color='green')
plt.title('simple linear regression')
plt.xlabel('position level')
plt.ylabel('Salary')
plt.show()
